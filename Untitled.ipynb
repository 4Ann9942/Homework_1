# %%
number='20'
print(number)
# Out:
# 20

# %%
escaping ="Немає з'єднання"
print(escaping)
# Out:
# Немає з'єднання

# %%
new_line = "Firs line\n Second line\n Third line"
print(new_line)
# Out:
# Firs line
#  Second line
#  Third line

# %%
message = '1234567890'
print(len(message))
# Out:
# 10

# %%
number_str = str(20)
print(type(number))
print(type(number_str))
# Out:
# <class 'str'>
# <class 'str'>

# %%
message = '123456789'
message [::-2]
# Out:
# '97531'

# %%
Pattern = 'Pattern text:(1,2,3)'
print(Pattern.format(3,2,1))
# Out:
# Pattern text:(1,2,3)

# %%
message = "Немає з'єднання"
print(message)
# Out:
# Немає з'єднання

# %%
1+2
# Out:
# 3

# %%
'1'+'2'
# Out:
# '12'

# %%
print(3*'1')
# Out:
# 111

# %%
direct_speech = 'Вона сказала "Я люблю тебе 3000 раз"'
print(direct_speech)
# Out:
# Вона сказала "Я люблю тебе 3000 раз"

# %%
welcome = "Hello! Welcome back home"
print(welcome)
# Out:
# Hello! Welcome back home

# %%
number_string = "123"
print(number_string)
# Out:
# 123

# %%
adding_line = 'first line'+\
             'second line'
print(adding_line)
# Out:
# first linesecond line

# %%
letter = 'A'
